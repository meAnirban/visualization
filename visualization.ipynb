# %%
import seaborn as sns
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import plotly as py
from plotly.offline import iplot
import plotly.tools as tls
import cufflinks as cf

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('mpg')
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# ### Plots of Series or dataframe (Pandas) using matplotlib in backend

# %%
# Plots of Series or dataframe (Pandas) using matplotlib in backend
df.plot() # plot all features against index column
# Out:
# <AxesSubplot:>

# %%
df.index
# Out:
# RangeIndex(start=0, stop=398, step=1)

# %%
df.mpg.plot()
# Out:
# <AxesSubplot:>

# %%
df.mpg.cumsum().plot()
# Out:
# <AxesSubplot:>

# %%
df['log_mpg'] = df.mpg.apply(lambda x: np.log(x))
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name   log_mpg
# 0          70    usa  chevrolet chevelle malibu  2.890372
# 1          70    usa          buick skylark 320  2.708050
# 2          70    usa         plymouth satellite  2.890372
# 3          70    usa              amc rebel sst  2.772589
# 4          70    usa                ford torino  2.833213

# %%
df['log_mpg'].plot(figsize=(10, 10))
# Out:
# <AxesSubplot:>

# %%
df['log_mpg'].plot(figsize=(10, 10), title  = "Log of mpg")
# Out:
# <AxesSubplot:title={'center':'Log of mpg'}>

# %%
gf = df['log_mpg'].plot(figsize=(5,5), title  = "Log of mpg")
gf.set_xlabel('index')
gf.set_ylabel('log(mpg)')
# Out:
# Text(0, 0.5, 'log(mpg)')

# %%
df.iloc[0][0:7].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df.iloc[0][0:7].plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
df[['mpg', 'acceleration']].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df[['mpg', 'acceleration']].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[['mpg', 'acceleration', 'log_mpg']].plot.hist(alpha = 0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['pow_hp'] = df.horsepower.apply(lambda x: x**2)

# %%
df[['mpg', 'acceleration']].plot.hist(bins= 20,alpha = 0.5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[['mpg', 'acceleration']].plot.hist(bins= 20, stacked = True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.hist(figsize=(10, 10), color = 'green')
# Out:
# array([[<AxesSubplot:title={'center':'mpg'}>,
#         <AxesSubplot:title={'center':'cylinders'}>,
#         <AxesSubplot:title={'center':'displacement'}>],
#        [<AxesSubplot:title={'center':'horsepower'}>,
#         <AxesSubplot:title={'center':'weight'}>,
#         <AxesSubplot:title={'center':'acceleration'}>],
#        [<AxesSubplot:title={'center':'model_year'}>,
#         <AxesSubplot:title={'center':'log_mpg'}>,
#         <AxesSubplot:title={'center':'pow_hp'}>]], dtype=object)

# %%
df.plot.scatter(x= 'displacement', y = 'acceleration')
# Out:
# <AxesSubplot:xlabel='displacement', ylabel='acceleration'>

# %%
df.plot.scatter(x= 'displacement', y = 'acceleration', c = 'mpg')
# Out:
# <AxesSubplot:xlabel='displacement', ylabel='acceleration'>

# %%
df.plot.scatter(x= 'horsepower', y = 'acceleration', c = 'mpg')
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='acceleration'>

# %%
df.plot.scatter(x= 'horsepower', y = 'acceleration', c = 'mpg',label = 'cars', s = 50)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='acceleration'>

# %%
df.plot.hexbin(x= 'horsepower', y = 'acceleration', gridsize = 10)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='acceleration'>

# %%
df.iloc[0][0:6].plot.pie(figsize = (8, 8))
# Out:
# <AxesSubplot:ylabel='0'>

# %%
df.head(2).T.iloc[0:4].plot.pie(subplots=True)
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>], dtype=object)

# %%
df.head(2).T.iloc[0:4].plot.pie(subplots=True, fontsize = 10, autopct = '%.2f')
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>], dtype=object)

# %%
pd.plotting.scatter_matrix(df, figsize = (10,10))
# Out:
# array([[<AxesSubplot:xlabel='mpg', ylabel='mpg'>,
#         <AxesSubplot:xlabel='cylinders', ylabel='mpg'>,
#         <AxesSubplot:xlabel='displacement', ylabel='mpg'>,
#         <AxesSubplot:xlabel='horsepower', ylabel='mpg'>,
#         <AxesSubplot:xlabel='weight', ylabel='mpg'>,
#         <AxesSubplot:xlabel='acceleration', ylabel='mpg'>,
#         <AxesSubplot:xlabel='model_year', ylabel='mpg'>,
#         <AxesSubplot:xlabel='log_mpg', ylabel='mpg'>,
#         <AxesSubplot:xlabel='pow_hp', ylabel='mpg'>],
#        [<AxesSubplot:xlabel='mpg', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='cylinders', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='displacement', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='horsepower', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='weight', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='acceleration', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='model_year', ylabel='cylinders'>,
# ...

# %%
pd.plotting.scatter_matrix(df, figsize = (10,10),diagonal='kde')
# Out:
# array([[<AxesSubplot:xlabel='mpg', ylabel='mpg'>,
#         <AxesSubplot:xlabel='cylinders', ylabel='mpg'>,
#         <AxesSubplot:xlabel='displacement', ylabel='mpg'>,
#         <AxesSubplot:xlabel='horsepower', ylabel='mpg'>,
#         <AxesSubplot:xlabel='weight', ylabel='mpg'>,
#         <AxesSubplot:xlabel='acceleration', ylabel='mpg'>,
#         <AxesSubplot:xlabel='model_year', ylabel='mpg'>,
#         <AxesSubplot:xlabel='log_mpg', ylabel='mpg'>,
#         <AxesSubplot:xlabel='pow_hp', ylabel='mpg'>],
#        [<AxesSubplot:xlabel='mpg', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='cylinders', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='displacement', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='horsepower', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='weight', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='acceleration', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='model_year', ylabel='cylinders'>,
# ...

# %%
df.mpg.plot(figsize= (10, 10), style = 'r--', legend = True)
# Out:
# <AxesSubplot:>

# %%
df.mpg.plot(figsize= (10, 10), style = '-.', legend = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## PLotly

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name   log_mpg   pow_hp
# 0          70    usa  chevrolet chevelle malibu  2.890372  16900.0
# 1          70    usa          buick skylark 320  2.708050  27225.0
# 2          70    usa         plymouth satellite  2.890372  22500.0
# 3          70    usa              amc rebel sst  2.772589  22500.0
# 4          70    usa                ford torino  2.833213  19600.0

# %%
# offline mode
py.offline.init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
# ...

# %%
df[['mpg','cylinders','displacement','horsepower',	'acceleration']].iplot()

# %%
df.iplot(x = 'displacement', y = 'acceleration', mode = 'markers', xTitle = 'disp', yTitle = 'acc')

# %%
cf.getTheme()
# Out:
# {'colorscale': 'original',
#  'linewidth': 1.3,
#  'bargap': 0.01,
#  'layout': {'legend': {'bgcolor': '#151516', 'font': {'color': '#D9D9D9'}},
#   'paper_bgcolor': '#151516',
#   'plot_bgcolor': '#151516',
#   'yaxis': {'tickfont': {'color': '#C2C2C2'},
#    'gridcolor': '#434343',
#    'titlefont': {'color': '#D9D9D9'},
#    'zerolinecolor': '#666570',
#    'showgrid': True},
#   'xaxis': {'tickfont': {'color': '#C2C2C2'},
#    'gridcolor': '#434343',
#    'titlefont': {'color': '#D9D9D9'},
#    'zerolinecolor': '#666570',
#    'showgrid': True},
#   'titlefont': {'color': '#D9D9D9'}},
#  'annotations': {'fontcolor': '#D9D9D9', 'arrowcolor': '#8C8C8C'}}

# %%
cf.set_config_file(theme = 'solar')
df.iplot(x = 'displacement', y = 'acceleration', mode = 'markers', xTitle = 'disp', yTitle = 'acc')

# %%
df.iplot(kind = 'bar', x = 'origin', y = 'mpg')

# %%
df[['mpg', 'acceleration']].iplot(kind = 'box')

# %%
df.iplot(x = 'mpg', y = 'acceleration', z = 'horsepower', kind = 'scatter3d')

# %%
df.iplot(x = 'mpg', y = 'acceleration', z = 'log_mpg', kind = 'bubble3d', size = 'cylinders')

# %%
import plotly.express as px

fig = px.scatter_matrix(df, dimensions = ['mpg','displacement','horsepower','acceleration'], color = "origin")
fig.show()

# %%
# parallel coordinates
fig = px.parallel_coordinates(df, color = "cylinders", labels = {'origin': 'origin',
                                                                 'mpg':'mpg','displacement':'displacement',
                                                                 'horsepower':'horsepower',
                                                                 'acceleration':'acceleration'},
                              color_continuous_scale=px.colors.diverging.Tealrose, color_continuous_midpoint=2)
fig.show()

# %%
px.data.gapminder()
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
px.data.gapminder().query("country == 'Afghanistan'")
# Out:
#         country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0   Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1   Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2   Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3   Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4   Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# 5   Afghanistan      Asia  1977   38.438  14880372  786.113360       AFG
# 6   Afghanistan      Asia  1982   39.854  12881816  978.011439       AFG
# 7   Afghanistan      Asia  1987   40.822  13867957  852.395945       AFG
# 8   Afghanistan      Asia  1992   41.674  16317921  649.341395       AFG
# 9   Afghanistan      Asia  1997   41.763  22227415  635.341351       AFG
# 10  Afghanistan      Asia  2002   42.129  25268405  726.734055       AFG
# 11  Afghanistan      Asia  2007   43.828  31889923  974.580338       AFG
#
#     iso_num
# ...

# %% [markdown]
# ### Seaborn

# %%
df = px.data.gapminder()
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
sns.relplot(data =df, x = 'pop', y = 'gdpPercap')

# %%
sns.relplot(data =df, x = 'pop', y = 'gdpPercap', hue = 'continent')

# %%
sns.relplot(data =df, x = 'pop', y = 'gdpPercap', hue = 'continent', style = 'continent')

# %%
sns.relplot(data =df, x = 'pop', y = 'gdpPercap', hue = 'continent', style = 'continent', size = 'lifeExp')

# %%
sns.relplot(data =df, x = 'year', y = 'gdpPercap', kind = 'line', sort = True, hue = 'continent')

# %%
sns.scatterplot(data =df, x = 'pop', y = 'gdpPercap')
# Out:
# <AxesSubplot:xlabel='pop', ylabel='gdpPercap'>

# %%
sns.catplot(data =df, x = 'continent', y = 'lifeExp')

# %%
sns.catplot(data =df, x = 'continent', y = 'lifeExp', kind = 'box')

# %%
sns.distplot(df['lifeExp'])
# Out:
# C:\Users\anirb\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='lifeExp', ylabel='Density'>

# %%
sns.jointplot(data =df, x = 'lifeExp', y = 'gdpPercap')

# %%
sns.jointplot(data =df, x = 'lifeExp', y = 'gdpPercap', kind = 'hex')

# %%
sns.pairplot(df)

# %%
sns.lmplot(data =df, x = 'lifeExp', y = 'gdpPercap')

# %%
sns.regplot(data =df, x = 'lifeExp', y = 'gdpPercap')
# Out:
# <AxesSubplot:xlabel='lifeExp', ylabel='gdpPercap'>

# %%
sns.lmplot(height=30, aspect=1, data =df, x = 'lifeExp', y = 'gdpPercap', col = 'continent')
